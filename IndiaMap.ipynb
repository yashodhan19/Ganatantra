# %%
import geopandas as gpd
import matplotlib

# %%
gdf = gpd.read_file('/Users/yashodhanjoglekar/Downloads/maps-master/States/Admin2.shp')
# %matplotlib inline
gdf.plot(column='ST_NM', cmap=None, legend=True, figsize=(12, 12))
gdf.plot(column='ST_NM', cmap=None)

# %%
userTime = df.groupby(['Cash (Cr)','username','jobcode_1']).agg({'hours':np.sum})
userTime = userTime.reset_index().sort_values(by = 'jobcode_2', ascending = True)
pivot = userTime.pivot(index='jobcode_2', columns='username', values='hours')
pivot.fillna(value=0, method=None, axis=None, inplace=True, limit=None, downcast=None)
